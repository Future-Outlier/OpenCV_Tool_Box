# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## 練習產生隨機dots的亂數img !

# %%
height=15
width=15
plt.figure(figsize=(12, 6))
plt.subplot(2,2,1)
image=np.zeros((height, width), np.float64)
plt.imshow(image, cmap='gray', vmin=0,vmax=255)
plt.title("Black")
image.fill(255)
plt.subplot(2,2,2)
plt.imshow(image, cmap='gray', vmin=0,vmax=255)
plt.title("White")
plt.subplot(2,2,3)
image = np.random.randint(256, size=[height, width])
plt.imshow(image, cmap='gray', vmin=0,vmax=255)
plt.title("Random Black and White !")
plt.show()
